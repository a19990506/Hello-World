# %%
import os
import jieba

# %%
texts = os.listdir('./data3')
texts
# Out:
# ['1.txt',
#  '10.txt',
#  '2.txt',
#  '3.txt',
#  '4.txt',
#  '5.txt',
#  '6.txt',
#  '7.txt',
#  '8.txt',
#  '9.txt']

# %%
corpus = []
for text in texts:
    with open('./data3/{}'.format(text), 'r',encoding = 'utf8') as file:
        corpus.append(file.read())

# %%
corpus_cut = [jieba.lcut(t) for t in corpus]
# 這樣就有斷完詞後的 list 了
corpus_cut
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Anita\AppData\Local\Temp\jieba.cache
# Loading model cost 0.690 seconds.
# Prefix dict has been built succesfully.
# [['\ufeff',
#   '一如',
#   '往常',
#   '的',
#   '來',
#   '到',
#   '了',
#   '全家',
#   ',',
#   '準備',
#   '拿',
#   '好',
#   '商品',
#   '結帳',
#   '時',
#   '\n',
#   '突然',
#   '發現',
#   '！',
#   '！',
#   '！',
#   'OMG',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '\n',
#   '我',
#   '最',
#   '愛',
#   'ㄉ',
#   '旺仔',
#   '小',
#   '饅頭',
#   '竟然',
#   '可以',
#   '配',
#   '上',
#   '牛奶',
#   ' ',
#   '這是',
#   '什麼',
#   '創新',
#   '的',
#   '發明',
#   '\n',
#   '\n',
#   '沒',
#   '看清楚',
#   '嗎',
#   '？',
#   '？',
#   '？',
#   '？',
#   '？',
#   '\n',
#   '\n',
#   '平常',
#   '我',
#   '很',
#   '愛喝',
#   '麥芽',
#   '牛奶',
#   '+',
#   '巧克力',
#   '脆片',
#   '\n',
#   '不',
#   '知道',
#   '這個',
#   '新款',
#   '喝起',
#   '來',
#   '怎麼樣',
#   ' ',
#   '剛剛查',
#   '了',
#   '才',
#   '發現',
#   '前',
#   '兩天',
# ...

# %%
data = [' '.join(lcut) for lcut in corpus_cut]
print(data)
# Out:
# ['\ufeff 一如 往常 的 來 到 了 全家 , 準備 拿 好 商品 結帳 時 \n 突然 發現 ！ ！ ！ OMG ! ! ! ! ! \n 我 最 愛 ㄉ 旺仔 小 饅頭 竟然 可以 配 上 牛奶   這是 什麼 創新 的 發明 \n \n 沒 看清楚 嗎 ？ ？ ？ ？ ？ \n \n 平常 我 很 愛喝 麥芽 牛奶 + 巧克力 脆片 \n 不 知道 這個 新款 喝起 來 怎麼樣   剛剛查 了 才 發現 前 兩天 新聞 有 報 \n \n - - - - - 我 中午 來 去 試試 ！ ！ ！ \n 分享 一下 今天 的 早餐 ~ ~ \n 麵 包 也 是 新品 喔   看到 有紅豆 就 馬 上 下手 \n 安內 49 元 ！ ！', '\ufeff 大家 好   今天 我們 要 講一個 大舌貝 的 故事 \n \n 有 一天 有 一天   大舌貝 一如 往常 的 走 在 路上 \n 途中 看到 了 很 欠 咬 的 呆呆 獸 \n \n 大舌貝 就 看 呆呆 獸 很 不 順眼 \n 於 是 就 咬 下去 了 \n \n 這時   另 一 隻 呆呆 獸 對 被 咬 的 呆呆 獸 說 ： \n 「 咦 ， 背後有 東西 欸 你 」 \n \n 沒錯   這段 對 話 就是 「 咦 ， 背 」 \n 也 就是 貽貝 的 誕生 了 ！ \n \n 那麼 我們 今天 就 來 吃貽貝 吧 ！ \n \n 等   等 一下 \n 先 不要 因為 我 開場 講了 一個 冷笑 話 就 走 RRRR \n \n 你們 先 聽 完嘛 \n Post   images \n 貽貝學 名叫 絲綢殼 菜 蛤 \n 又名 「 淡菜 」 \n \n 富含 肌酸 、 蛋白 質 、 β   - 丙胺 酸 、 胺基酸 、 β - 羥基 - β - 甲基 丁酸 \n 對 身體 營養 跟 肌肉 很 有 幫助 \n Post   images \n 想成 為 大 肌 肌 嗎 ？ \n \n 那 就 跟 我 一起 來 做 \n 《 赤紅 芭樂 酸奶 醬貽貝佐 起司 螺旋 麵 包 》 \n \n 快來 準備 材料 ㄅ \n Post   images \n ● 海鮮 材料 \n 1 .   淡菜 1kg \n \n ● 香料 材料 \n 1 .   大蒜 5 瓣 \n 2 .   百里香 5 株
# ...

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#      \n            !      #      $      (      )      *      +      ,  ...    \
# 0  True  True   True  False  False  False  False  False   True   True  ...
# 1  True  True  False   True  False   True   True   True  False  False  ...
# 2  True  True  False  False   True  False  False  False   True  False  ...
# 3  True  True  False  False  False  False  False  False  False  False  ...
# 4  True  True  False   True   True  False  False  False  False  False  ...
#
#       ！      ＆      （      ）      ，      ：      ；      ？      ～      🥰
# 0  True  False  False  False  False  False  False   True  False  False
# 1  True   True   True  False   True   True  False   True  False  False
# 2  True  False   True   True  False   True  False   True   True  False
# 3  True  False   True   True   True   True   True  False   True  False
# 4  True  False   True   True   True   True  False  False  False  False
#
# [5 rows x 894 columns]

# %%
# sup = apriori(df, min_support = 0.01, use_colnames=True)
# sup

# %%
# rules = association_rules(sup, metric="confidence", min_threshold= 0.1)
# rules.tail()
